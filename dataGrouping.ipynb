# %% [markdown]
# <a href="https://colab.research.google.com/github/beloiual/gendered-lyrics/blob/main/dataGrouping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bash Terminal

# %%
# !git clone https://github.com/beloiual/gendered-lyrics
# Out:
# Cloning into 'gendered-lyrics'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 25 (delta 7), reused 5 (delta 1), pack-reused 0
# Unpacking objects: 100% (25/25), done.

# %% [markdown]
# Reads the Json file data

# %%
import json
import pandas as pd

with open("gendered-lyrics/Data/freqs.json","r") as fp:
  lyricDict=json.load(fp) #stores the values inside the dict

with open("gendered-lyrics/Data/gender-and-genre.json","r") as fp:
  demoDict=json.load(fp) #stores the values inside the dict
# Out:
# dict_keys(['BTS', 'Ariana Grande', 'Shawn Mendes', 'Pentatonix', 'Mariah Carey', 'Michael Buble', 'Luke Combs', 'Billie Eilish', 'Morgan Wallen', 'Bad Bunny', 'Bing Crosby', 'Carrie Underwood', 'Justin Bieber', 'Juice WRLD', 'The Weeknd', 'Lil Baby', 'Harry Styles', 'Andy Williams', 'Taylor Swift', 'Nat King Cole', 'Megan Thee Stallion', 'Chris Stapleton', 'Frank Sinatra', 'Pop Smoke', 'Post Malone', 'Dolly Parton', 'Dua Lipa', 'Drake', 'Vince Guaraldi Trio', 'DaBaby', 'The Beatles', 'Brenda Lee', 'Miley Cyrus', 'Gabby Barrett', 'AC/DC', 'Dean Martin', 'Gene Autry', 'Dan + Shay', 'Burl Ives', 'Elvis Presley', 'Queen', 'Trans-Siberian Orchestra', '24kGoldn', 'Kelly Clarkson', 'Bobby Helms', 'Ava Max', 'Fleetwood Mac', 'Lewis Capaldi', 'Josh Groban', 'The Kid LAROI', 'Eagles', 'The White Stripes', 'AJR', 'Khalid', 'Blake Shelton', 'Young Thug', 'Roddy Ricch', 'Wham!', 'Sam Smith', 'Perry Como', 'Jose Feliciano', 'Lee Brice', 'Chris Brown', 'Gwen Stefani', 'Travis Scott', 'The Ronettes', 'Kane Brown', 'Lil Nas X', 'Bruce Springsteen & The E Street Band', 'Darlene Love', 'Halsey', 'NCT', 'TWICE', 'Russell Dickerson', 'The Beach Boys', 'Jack Harlow', 'Polo G', 'Jon Pardi', 'Garth Brooks', 'King Von', 'Chris Lane', 'Ed Sheeran', 'Johnny Mathis', 'Moneybagg Yo', 'Nirvana', 'H.E.R.', 'Lil Durk', 'The Jacksons', 'Jason Derulo', 'John Legend', 'Jhene Aiko', 'Andrea Bocelli', 'Chuck Berry', 'Michael Jackson', 'Stevie Wonder', 'Parker McCollum', 'Pink Floyd', 'Paul McCartney', 'blackbear', 'Machine Gun Kelly'])
# {'Male': {'i': 2368, 'woke': 11, 'up': 1115, 'working': 6, 'like': 585, "i'm": 721, 'mexican': 4, 'that': 846, 'mean': 23, 'work': 36, 'from': 165, '10': 24, 'to': 980, 'then': 136, 'again': 14, 'nightmares': 6, 'of': 386, 'losing': 4, 'everything': 40, 'boost': 4, 'my': 1373, 'adrenaline': 4, 'bitch': 254, 'do': 224, 'what': 272, 'feel': 130, 'how': 158, 'got': 610, 'drink': 52, 'on': 967, 'the': 3026, 'rise': 6, 'house': 37, 'hill
't": 278, 'till': 5, "dawg's": 1, 'seen': 23, 'brick': 9, 'buy': 22, "don't": 438, 'wish': 19, 'chance': 5, 'she': 447, 'turned': 14, 'around': 80, 'said': 71, 'stack': 17, 'belt': 3, 'double': 19, 'm': 89, 'cult': 1, "mastermind's": 1, '16': 1, 's': 31, 'coke': 12, 'verses': 4, 'dope': 40, 'xxl': 2, "'cause": 70, 'source': 1, 'quotes': 1, "i've": 60, 'held': 2, 'ten': 12, 'tens': 3, "won't": 39, 'sin': 6, 'bring': 20, 'hell': 35, 'residence': 6, 'godly': 1, 'presence': 1, 'presidents': 1, 'job': 7, 'made': 52, 'public': 2, 'housing': 1, 'fence': 5, 'college': 7, 'make': 164, 'sense': 4, 'whole': 60, 'home': 54, 'invaded': 1, 'quick': 8, 'did': 56, 'dues': 3, 'induced': 1, 'overdue': 2, 'one': 193, 'voodoo': 1, 'want': 154, 'apes': 1, 'jump': 23, 'mountain': 3, 'problem': 5, 'plus': 3, 'issues': 1, "can't": 197, 'solve': 6, "it's": 356, "nothin'": 23, 'couch': 6, "fuckin'": 38, "somethin'": 16, 'please': 43, 'mama': 67, "comin'": 18, "'til": 42, 'hundred': 41, 'scratch': 1, 'million': 5, 'stretch': 4, 'trillion': 1, 'knew': 28 ...
# None

# %% [markdown]
# Find the demographics of each singer.

# %%
popDict={}
rockDict={}
hiphopDict={}
soulDict={}
edmDict={}
rbDict={}
alternativeDict={}
countryDict={}
jazzDict={}
metalDict={}
folkDict={}
punkDict={}

maleDict={}
femaleDict={}
OtherValue={}
for i in demoDict:
  array=demoDict[i]
  if array[1] == "Pop": #check if the demographics of the artist is "pop" or any genre
    popDict.update({i:i})
  elif array[1] == "Hip-Hop":
    hiphopDict.update({i:i})
  elif array[1] == "Rock":
    rockDict.update({i:i})
  elif array[1] == "Soul":
    soulDict.update({i:i})
  elif array[1] == "EDM":
    edmDict.update({i:i})
  elif array[1] == "R&B":
    rbDict.update({i:i})
  elif array[1] == "Alternative":
    alternativeDict.update({i:i})
  elif array[1] == "Country":
    countryDict.update({i:i})
  elif array[1] == "Jazz":
    jazzDict.update({i:i})
  elif array[1] == "Metal":
    metalDict.update({i:i})
  elif array[1] == "Folk":
    folkDict.update({i:i})
  elif array[1] == "Punk":
    punkDict.update({i:i})
 
  if array[0] == 'Male': #checks gender of the artist
    maleDict.update({i:i})
  elif array[0] == 'Female':
    femaleDict.update({i:i})
  elif array[0] == 'Other':
    OtherValue.update({i:i})
# Out:
# {'Michael Buble': 'Michael Buble', 'Bing Crosby': 'Bing Crosby', 'Nat King Cole': 'Nat King Cole', 'Frank Sinatra': 'Frank Sinatra', 'Vince Guaraldi Trio': 'Vince Guaraldi Trio', 'Dean Martin': 'Dean Martin', 'Josh Groban': 'Josh Groban', 'Darlene Love': 'Darlene Love', 'Johnny Mathis': 'Johnny Mathis', 'Stevie Wonder': 'Stevie Wonder'}

# %% [markdown]
# Goes through the lyric dictionary and assigns each lyric to a genre or gender

# %%
popValue={}
rockValue={}
hiphopValue={}
soulValue={}
edmValue={}
rbValue={}
alternativeValue={}
countryValue={}
jazzValue={}
metalValue={}
folkValue={}
punkValue={}

maleValue={}
FemaleValue={}
otherValue={}

for i in lyricDict: #for each key value in lyricDict, checks if it is an artist in a certain genre
  if i in popDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in popValue:
        popValue[j]=popValue[j]+value2[j]
      else:
        popValue.update({j:lyric[j]})
  elif i in rockDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in rockValue:
        rockValue[j]=rockValue[j]+value2[j]
      else:
        rockValue.update({j:lyric[j]})
  elif i in hiphopDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in hiphopValue:
        hiphopValue[j]=hiphopValue[j]+value2[j]
      else:
        hiphopValue.update({j:lyric[j]})
  elif i in soulDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in soulValue:
        soulValue[j]=soulValue[j]+value2[j]
      else:
        soulValue.update({j:lyric[j]})
  elif i in edmDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in edmValue:
        edmValue[j]=edmValue[j]+value2[j]
      else:
        edmValue.update({j:lyric[j]})
  elif i in rbDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in rbValue:
        rbValue[j]=rbValue[j]+value2[j]
      else:
        rbValue.update({j:lyric[j]})
  elif i in alternativeDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in alternativeValue:
        alternativeValue[j]=alternativeValue[j]+value2[j]
      else:
        alternativeValue.update({j:lyric[j]})
  elif i in countryDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in countryValue:
        countryValue[j]=countryValue[j]+value2[j]
      else:
        countryValue.update({j:lyric[j]})
  elif i in jazzDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in jazzValue:
        jazzValue[j]=jazzValue[j]+value2[j]
      else:
        jazzValue.update({j:lyric[j]})
  elif i in metalDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in metalValue:
        metalValue[j]=metalValue[j]+value2[j]
      else:
        metalValue.update({j:lyric[j]})
  elif i in folkDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in folkValue:
        folkValue[j]=folkValue[j]+value2[j]
      else:
        folkValue.update({j:lyric[j]})
  elif i in punkDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in punkValue:
        punkValue[j]=punkValue[j]+value2[j]
      else:
        punkValue.update({j:lyric[j]})
  
  if i in maleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in maleValue:
        maleValue[j]=maleValue[j]+value2[j]
      else:
        maleValue.update({j:lyric[j]})
  elif i in femaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in FemaleValue:
        femaleValue[j]=femaleValue[j]+value2[j]
      else:
        femaleValue.update({j:lyric[j]})
  elif i in otherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in otherValue:
        otherValue[j]=otherValue[j]+value2[j]
      else:
        otherValue.update({j:lyric[j]})
# Out:
# {'i': 8212, 'was': 779, 'a': 5642, 'stranger': 13, 'in': 3762, 'the': 9201, 'city': 65, 'out': 607, 'of': 2840, 'town': 144, 'were': 329, 'people': 198, 'knew': 161, 'had': 303, 'that': 2747, 'feeling': 125, 'self-pity': 2, 'what': 985, 'to': 5825, 'do': 1262, 'outlook': 2, 'decidedly': 2, 'blue': 274, 'but': 1428, 'as': 890, 'walked': 23, 'through': 424, 'foggy': 13, 'streets': 26, 'alone': 247, 'it': 2321, 'turned': 53, 'be': 2295, 'luckiest': 4, 'day': 836, "i've": 579, 'known': 46, 'london': 16, 'me': 4137, 'low': 58, 'and': 6324, 'down': 554, 'viewed': 3, 'morning': 177, 'with': 1645, 'alarm': 4, 'british': 3, 'museum': 4, 'lost': 110, "it's": 1206, 'charm': 23, 'how': 774, 'long': 442, 'wondered': 5, 'could': 492, 'this': 899, 'thing': 217, 'last': 156, 'age': 8, 'miracles': 6, "hadn't": 10, 'passed': 23, 'for': 2213, 'suddenly': 30, 'saw': 88, 'you': 8904
'last': 18, 'or': 68, "you'll": 67, 'wake': 7, 'someday': 7, 'find': 44, 'chances': 1, 'have': 121, 'passed': 4, "you've": 41, 'been': 38, 'very': 11, 'fast': 5, "there'll": 19, 'hot': 22, 'time': 62, 'town': 40, 'berlin': 13, 'yanks': 4, 'marching': 4, 'wanna': 9, 'boy': 27, 'spread': 6, 'some': 49, 'joy': 28, 'they': 96, 'take': 53, 'old': 77, 'brooklyn': 2, 'boys': 7, 'begin': 14, 'joint': 3, 'apart': 8, 'tear': 6, 'down': 82, "they're": 17, 'gonna': 39, 'start': 23, 'row': 4, 'show': 12, 'them': 28, 'how': 108, 'paint': 3, 'back': 36, 'kokomo': 1, 'hike': 2, 'through': 55, "hitler's": 2, 'reich': 2, 'change': 11, 'heil': 2, 'whatcha-know-joe': 1, 'could': 70, 'keep': 38, 'em': 3, 'happy': 45, 'farm': 2, 'jubilee': 1, 'michigan': 1, 'gimme': 2, 'skin': 4, 'along': 29, 'get': 82, 'ready': 5, 'wear': 5, 'grand': 11, 'brand-new': 1, 'gown': 5, 'going': 6, 'meeting': 5, 'this': 92, 'good': 60, 'everybody': 4, "rabbit's": 1, 'foot': 8, 'hoodoos': 1, 'hear': 83, "preachin'": 1, 'has': 33, 'bend': 1, 'low': 11, 'drive': 1, 'sin': 2, 'religion': 1, 'shout': 6, 'sing': 43, 'tonight': 27, 'baby': 35, 'bells': 40, 'dingaling': 2, 'turn': 15, 'sweetly': 2, 'must': 20, 'birds': 11, 'too': 53, 'poets': 2, 'will': 124, 'join': 8, 'girls': 11, 'miss': 17, 'gonzola': 1, 'davis': 1, 'gondoola': 1, 'brown': 8, 'henrietta': 1, 'caesar': 1, "she's": 15, 'dressed': 4, 'red': 3, 'hug': 1, 'her': 124, 'then': 49, 'she': 118, 'said': 40, 'please': 18, 'fall': 14, 'are': 121, 'mine': 27, 'best': 8, "i'll": 100, 'no': 109, 'at': 76, 'feel': 23, 'well': 52, 'tell': 34, 'bing': 18, 'about': 37, 'found': 26, 'idea': 2, "i'm": 204, 'sure': 13, 'real': 4, 'yip': 5, 'de': 26, 'hootie': 2, 'got': 118, 'beauty': 2, 'dream': 69, 'yes': 53, 'cock': 1, 'cock-a-doodle': 2, "you're": 95, 'off': 18, 'noodle': 2, 'beam': 2, "'cause": 29, "couldn't": 5, 'knock':  ...

# %% [markdown]
# Groups all words by genre or gender.

# %%
genderDict={}
genreDict={}

genderDict.update({'Male':maleValue}) #puts the dictionaries from the previous line of code into more general dictionaries
genderDict.update({'Female':femaleValue})
genderDict.update({'Other':otherValue})

genreDict.update({'Pop':popValue})
genreDict.update({'Rock':rockValue})
genreDict.update({'Hip-Hop':hiphopValue})
genreDict.update({'Soul':soulValue})
genreDict.update({'EDM':edmValue})
genreDict.update({'R&B':rbValue})
genreDict.update({'Alternative':alternativeValue})
genreDict.update({'Country':countryValue})
genreDict.update({'Jazz':jazzValue})
genreDict.update({'Metal':metalValue})
genreDict.update({'Folk':folkValue})
genreDict.update({'Punk':punkValue})

# %% [markdown]
# Groups the artists into a specific category

# %%
popMaleDict={}
popFemaleDict={}
popOtherDict={}

rockMaleDict={}
rockFemaleDict={}
rockOtherDict={}

hiphopMaleDict={}
hiphopFemaleDict={}
hiphopOtherDict={}

soulMaleDict={}
soulFemaleDict={}
soulOtherDict={}

edmMaleDict={}
edmFemaleDict={}
edmOtherDict={}

rbMaleDict={}
rbFemaleDict={}
rbOtherDict={}

alternativeMaleDict={}
alternativeFemaleDict={}
alternativeOtherDict={}

countryMaleDict={}
countryFemaleDict={}
countryOtherDict={}

jazzMaleDict={}
jazzFemaleDict={}
jazzOtherDict={}

metalMaleDict={}
metalFemaleDict={}
metalOtherDict={}

folkMaleDict={}
folkFemaleDict={}
folkOtherDict={}

punkMaleDict={}
punkFemaleDict={}
punkOtherDict={}



for i in demoDict:
  array=demoDict[i]
  if array[1] == "Pop": #checks if an artist is a pop singer from the demoDict
    if array[0] == 'Male': #checks what gender they are
      popMaleDict.update({i:i}) #adds the artist to a dictionary with only male pop artists.
    elif array[0] == 'Female':
      popFemaleDict.update({i:i})
    elif array[0] == 'Other':
      popOtherDict.update({i:i})
  elif array[1] == "Hip-Hop":
    if array[0] == 'Male':
      hiphopMaleDict.update({i:i})
    elif array[0] == 'Female':
      hiphopFemaleDict.update({i:i})
    elif array[0] == 'Other':
      hiphopOtherDict.update({i:i})
  elif array[1] == "Rock":
    if array[0] == 'Male':
      rockMaleDict.update({i:i})
    elif array[0] == 'Female':
      rockFemaleDict.update({i:i})
    elif array[0] == 'Other':
      rockOtherDict.update({i:i})
  elif array[1] == "Soul":
    if array[0] == 'Male':
      soulMaleDict.update({i:i})
    elif array[0] == 'Female':
      soulFemaleDict.update({i:i})
    elif array[0] == 'Other':
      soulOtherDict.update({i:i})
  elif array[1] == "EDM":
    if array[0] == 'Male':
      edmMaleDict.update({i:i})
    elif array[0] == 'Female':
      edmFemaleDict.update({i:i})
    elif array[0] == 'Other':
      edmOtherDict.update({i:i})
  elif array[1] == "R&B":
    if array[0] == 'Male':
      rbMaleDict.update({i:i})
    elif array[0] == 'Female':
      rbFemaleDict.update({i:i})
    elif array[0] == 'Other':
      rbOtherDict.update({i:i})
  elif array[1] == "Alternative":
    if array[0] == 'Male':
      alternativeMaleDict.update({i:i})
    elif array[0] == 'Female':
      alternativeFemaleDict.update({i:i})
    elif array[0] == 'Other':
      alternativeOtherDict.update({i:i})
  elif array[1] == "Country":
    if array[0] == 'Male':
      countryMaleDict.update({i:i})
    elif array[0] == 'Female':
      countryFemaleDict.update({i:i})
    elif array[0] == 'Other':
      countryOtherDict.update({i:i})
  elif array[1] == "Jazz":
    if array[0] == 'Male':
      jazzMaleDict.update({i:i})
    elif array[0] == 'Female':
      jazzFemaleDict.update({i:i})
    elif array[0] == 'Other':
      jazzOtherDict.update({i:i})
  elif array[1] == "Metal":
    if array[0] == 'Male':
      metalMaleDict.update({i:i})
    elif array[0] == 'Female':
      metalFemaleDict.update({i:i})
    elif array[0] == 'Other':
      metalOtherDict.update({i:i})
  elif array[1] == "Folk":
    if array[0] == 'Male':
      folkMaleDict.update({i:i})
    elif array[0] == 'Female':
      folkFemaleDict.update({i:i})
    elif array[0] == 'Other':
      folkOtherDict.update({i:i})
  elif array[1] == "Punk":
    if array[0] == 'Male':
      punkMaleDict.update({i:i})
    elif array[0] == 'Female':
      punkFemaleDict.update({i:i})
    elif array[0] == 'Other':
      punkOtherDict.update({i:i})

# %% [markdown]
# Reads through the lyric dictionary and assigns values to words within a certain demographic (Both gender and Genre)

# %%
popMaleValue={}
popFemaleValue={}
popOtherValue={}

rockMaleValue={}
rockFemaleValue={}
rockOtherValue={}

hiphopMaleValue={}
hiphopFemaleValue={}
hiphopOtherValue={}

soulMaleValue={}
soulFemaleValue={}
soulOtherValue={}

edmMaleValue={}
edmFemaleValue={}
edmOtherValue={}

rbMaleValue={}
rbFemaleValue={}
rbOtherValue={}

alternativeMaleValue={}
alternativeFemaleValue={}
alternativeOtherValue={}

countryMaleValue={}
countryFemaleValue={}
countryOtherValue={}

jazzMaleValue={}
jazzFemaleValue={}
jazzOtherValue={}

metalMaleValue={}
metalFemaleValue={}
metalOtherValue={}

folkMaleValue={}
folkFemaleValue={}
folkOtherValue={}

punkMaleValue={}
punkFemaleValue={}
punkOtherValue={}

for i in lyricDict: #for each artist in lyric dictionary
  if i in popMaleDict: #check if artist is a pop male singer
    lyric=lyricDict[i]
    for j in lyric: #goes through each lyric
      value2=lyric
      if j in popMaleValue: #if the lyric is present, add the amount of times it appears.
        popMaleValue[j]=popMaleValue[j]+value2[j]
      else: #if it is not present, update it into the dictionary
        popMaleValue.update({j:lyric[j]})

  elif i in popFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in popFemaleValue:
        popFemaleValue[j]=popFemaleValue[j]+value2[j]
      else:
        popFemaleValue.update({j:lyric[j]})
  elif i in popOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in popOtherValue:
        popOtherValue[j]=popOtherValue[j]+value2[j]
      else:
        popOtherValue.update({j:lyric[j]})

        
  elif i in rockMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in rockMaleValue:
        rockMaleValue[j]=rockMaleValue[j]+value2[j]
      else:
        rockMaleValue.update({j:lyric[j]})
  elif i in rockFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in rockFemaleValue:
        rockFemaleValue[j]=rockFemaleValue[j]+value2[j]
      else:
        rockFemaleValue.update({j:lyric[j]})
  elif i in rockOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in rockOtherValue:
        rockOtherValue[j]=rockOtherValue[j]+value2[j]
      else:
        rockOtherValue.update({j:lyric[j]})

  elif i in hiphopMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in hiphopMaleValue:
        hiphopMaleValue[j]=hiphopMaleValue[j]+value2[j]
      else:
        hiphopMaleValue.update({j:lyric[j]})
  elif i in hiphopFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in hiphopFemaleValue:
        hiphopFemaleValue[j]=hiphopFemaleValue[j]+value2[j]
      else:
        hiphopFemaleValue.update({j:lyric[j]})
  elif i in hiphopOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in hiphopOtherValue:
        hiphopOtherValue[j]=hiphopOtherValue[j]+value2[j]
      else:
        hiphopOtherValue.update({j:lyric[j]})
  
  elif i in soulMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in soulMaleValue:
        soulMaleValue[j]=soulMaleValue[j]+value2[j]
      else:
        soulMaleValue.update({j:lyric[j]})
  elif i in soulFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in soulFemaleValue:
        soulFemaleValue[j]=soulFemaleValue[j]+value2[j]
      else:
        soulFemaleValue.update({j:lyric[j]})
  elif i in soulOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in soulOtherValue:
        soulOtherValue[j]=soulOtherValue[j]+value2[j]
      else:
        soulOtherValue.update({j:lyric[j]})


  elif i in edmMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in edmMaleValue:
        edmMaleValue[j]=edmMaleValue[j]+value2[j]
      else:
        edmMaleValue.update({j:lyric[j]})
  elif i in edmFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in edmFemaleValue:
        edmFemaleValue[j]=edmFemaleValue[j]+value2[j]
      else:
        edmFemaleValue.update({j:lyric[j]})
  elif i in edmOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in edmOtherValue:
        edmOtherValue[j]=edmOtherValue[j]+value2[j]
      else:
        edmOtherValue.update({j:lyric[j]})



  elif i in rbMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in rbMaleValue:
        rbMaleValue[j]=rbMaleValue[j]+value2[j]
      else:
        rbMaleValue.update({j:lyric[j]})
  elif i in rbFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in rbFemaleValue:
        rbFemaleValue[j]=rbFemaleValue[j]+value2[j]
      else:
        rbFemaleValue.update({j:lyric[j]})
  elif i in rbOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in rbOtherValue:
        rbOtherValue[j]=rbOtherValue[j]+value2[j]
      else:
        rbOtherValue.update({j:lyric[j]})

  elif i in alternativeMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in alternativeMaleValue:
        alternativeMaleValue[j]=alternativeMaleValue[j]+value2[j]
      else:
        alternativeMaleValue.update({j:lyric[j]})
  elif i in alternativeFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in alternativeFemaleValue:
        alternativeFemaleValue[j]=alternativeFemaleValue[j]+value2[j]
      else:
        alternativeFemaleValue.update({j:lyric[j]})
  elif i in alternativeOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in alternativeOtherValue:
        alternativeOtherValue[j]=alternativeOtherValue[j]+value2[j]
      else:
        alternativeOtherValue.update({j:lyric[j]})



  elif i in countryMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in countryMaleValue:
        countryMaleValue[j]=countryMaleValue[j]+value2[j]
      else:
        countryMaleValue.update({j:lyric[j]})
  elif i in countryFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in countryFemaleValue:
        countryFemaleValue[j]=countryFemaleValue[j]+value2[j]
      else:
        countryFemaleValue.update({j:lyric[j]})
  elif i in countryOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in countryOtherValue:
        countryOtherValue[j]=countryOtherValue[j]+value2[j]
      else:
        countryOtherValue.update({j:lyric[j]})


  elif i in jazzMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in jazzMaleValue:
        jazzMaleValue[j]=jazzMaleValue[j]+value2[j]
      else:
        jazzMaleValue.update({j:lyric[j]})
  elif i in jazzFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in jazzFemaleValue:
        jazzFemaleValue[j]=jazzFemaleValue[j]+value2[j]
      else:
        jazzFemaleValue.update({j:lyric[j]})
  elif i in jazzOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in jazzOtherValue:
        jazzOtherValue[j]=jazzOtherValue[j]+value2[j]
      else:
        jazzOtherValue.update({j:lyric[j]})

    
  elif i in metalMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in metalMaleValue:
        metalMaleValue[j]=metalMaleValue[j]+value2[j]
      else:
        metalMaleValue.update({j:lyric[j]})
  elif i in metalFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in metalFemaleValue:
        metalFemaleValue[j]=metalFemaleValue[j]+value2[j]
      else:
        metalFemaleValue.update({j:lyric[j]})
  elif i in metalOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in metalOtherValue:
        metalOtherValue[j]=metalOtherValue[j]+value2[j]
      else:
        metalOtherValue.update({j:lyric[j]})

  elif i in folkMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in folkMaleValue:
        folkMaleValue[j]=folkMaleValue[j]+value2[j]
      else:
        folkMaleValue.update({j:lyric[j]})
  elif i in folkFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in folkFemaleValue:
        folkFemaleValue[j]=folkFemaleValue[j]+value2[j]
      else:
        folkFemaleValue.update({j:lyric[j]})

  elif i in punkMaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in punkMaleValue:
        punkMaleValue[j]=punkMaleValue[j]+value2[j]
      else:
        punkMaleValue.update({j:lyric[j]})
  elif i in punkFemaleDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in punkFemaleValue:
        punkFemaleValue[j]=punkFemaleValue[j]+value2[j]
      else:
        punkFemaleValue.update({j:lyric[j]})
  elif i in punkOtherDict:
    lyric=lyricDict[i]
    for j in lyric:
      value2=lyric
      if j in punkOtherValue:
        punkOtherValue[j]=punkOtherValue[j]+value2[j]
      else:
        punkOtherValue.update({j:lyric[j]})
  

  
  
print(popMaleValue)
print(lyricDict["Shawn Mendes"])
# Out:
# {'chorus': 2162, 'all': 5347, "it'd": 37, 'take': 1857, 'is': 4283, '24': 51, 'hours': 113, 'sign': 73, 'the': 21983, 'check': 103, 'and': 12948, 'place': 432, 'ours': 40, "it's": 3632, 'a': 12242, 'little': 830, 'soon': 162, 'but': 4266, 'i': 28178, 'wanna': 2199, 'come': 1667, 'home': 811, 'to': 13490, 'you': 26530, 'verse': 1728, '1': 772, "don't": 5168, 'know': 5109, 'how': 1648, 'does': 202, 'it': 10643, 'go': 2657, 'promise': 222, 'that': 7618, 'love': 5831, 'so': 4466, "i'll": 1918, 'bet': 153, 'on': 6299, 'me': 14056, "you're": 2366, 'bulletproof': 2, "let's": 580, 'throw': 207, 'away': 1174, 'our': 709, 'backup': 2, 'plans': 66, 'people': 435, 'might': 321, 'not': 1662, 'understand': 204, 'who': 864, 'cares': 44, 'about': 1237, 'if': 2995, 'they': 1999, 'approve': 6, "i'd": 476, 'face': 443, 'them': 866, 'be': 5456, 'with': 4362, 'we': 4764, 'could': 1349, 'dance': 320, 'flowers': 41, '2': 869, 'heard': 221, 'once': 247, 'wise': 43, 'man': 995, 'said': 933, 'only': 1174, 'fools': 24, 'rushing': 10, 'in': 8455, "i'm": 7551, 'type': 86, 'overthink': 6, 'when': 3469, 'something': 491, 'feels': 213, 'right': 1645, 'mean': 374, 'every': 835, 'word': 128, 'paint': 53, 'world': 908, 'deserve': 84, 'color': 31, "you'd": 186, 'imagine': 36, "can't": 2088, 'wait': 294, 'for': 5030, 'happen': 73, "'cause": 1129, '3': 226, 'intro': 286, '05': 8, 'rollercoaster': 12, 'ride': 334, 'hoping': 75, 'change': 448, 'your': 6472, 'mind': 825, 'let': 2120, 'never': 2257, 'been': 1560, 'sure': 192, 'my': 10829, 'life': 1326, 'sunlight': 13, 'rainy': 13, 'day': 1242, 'would': 886, 'heart': 1391, 'walked': 86, 'mess': 89, 'now': 2859, 'wreck': 21, 'waiting': 207, 'moment': 217, 'down': 2036, 'cut': 103, 'cord': 4, 'what': 3434, 'do': 3428, 'skydive': 1, 'without': 421, 'parachute': 2, 'baby': 3133, 'help': 277, 'out': 2263, 'scared': 128, 'gonna': 1162, 'wake': 331, 'up': 4400, "you'll": 571, 'pre-chorus': 529, 'this': 3708, 'feeling': 474, "doesn't": 114, 'fade': 68, 'no': 3601, 'matter': 201, 'hard': 490, 'try': 532, 'always': 697, 'think': 954, 'at': 1637, 'same': 419, 'time': 2170, 'night': 1228, 'terrified': 7, 'turn': 448, 'around': 791, 'say': 2052, 'goodbye': 164, "i've": 1069, "there's": 779, 'door': 232, 'heaven': 222, 'key': 67, 'had': 773, 'beg': 42, 'knees': 76, 'oh': 4287, 'please': 364, 'anything': 180, 'has': 262, 'changed': 102, 'one': 2247, 'next': 229, 'bridge': 425, 'want': 2125, 'fly': 353, 'darling': 135, 'yeah': 4300, 'ooh-ooh': 35, 'she': 3166, 'show': 657, 'was': 1871, 'afraid': 116, 'being': 149, 'alone': 556, 'too': 1228, 'much': 552, 'though': 376, 'everyone': 99, 'strong': 128, "didn't": 317, 'barely': 24, 'carry': 40, 'knew': 218, 'okay': 205, 'get': 2785, 'her': 2007, 'way': 1599, 'sometimes': 211, 'gets': 129, 'gotta': 915, 'realize': 53, 'fog': 12, 'will': 1464, 'clear': 91, 'have': 1631, 'because': 314, "we're": 775, 'tell': 1665, 'herself': 13, 'use': 103, 'just': 4258, 'fine': 192, 'got': 3441, 'loose': 35, 'focus': 28, 'hand': 366, "we'll": 438, 'leave': 651, 'tomorrow': 163, 'sleep': 291, 'make': 2047, 'things': 592, 'breakfast': 17, 'like': 4532, 'before': 561, 'stay': 666, 'here': 1249, 'lay': 211, 'arms': 241, 'gone': 568, 'am': 683, 'keeping': 54, 'warm': 123, 'act': 123, 'can': 3112, 'more': 1133, 'lying': 67, 'bed': 223, 'whether': 13, 'wrong': 331, 'or': 871, 'sense': 69, 'of': 5263, 'morning': 253, 'over': 779, 'forget': 305, 'watch': 298, 'sneak': 17, 'asleep': 46, 'miles': 59, 'road': 161, 'wishing': 33, 'everything': 527, 'dream': 421, 're-rewind': 1, 'friday': 23, 'lies': 113, 'where': 1067, 'headed': 19, 'probably': 92, "should've": 65, 'known': 105, 'pretty': 221, 'forgive': 39, 'fool': 156, 'told': 429, 'twice': 67, 'regret': 85, 'turns': 27, 'replace': 21, 'permanent': 9, 'erase': 17, 'remember': 392, 'kiss': 504, 'takes': 84, 'memory': 48, 'aftertaste': 5, 'close': 344, 'eyes': 783, 'hide': 161, 'everywhere': 116, 'smell': 45, 'sheets': 51, "weren't": 34, 'ready': 296, 'left': 366, 'there ...
# {'chorus': 109, 'all': 188, "it'd": 10, 'take': 101, 'is': 133, '24': 7, 'hours': 10, 'sign': 8, 'the': 493, 'check': 6, 'and': 461, 'place': 16, 'ours': 11, "it's": 168, 'a': 248, 'little': 63, 'soon': 10, 'but': 174, 'i': 1215, 'wanna': 91, 'come': 41, 'home': 26, 'to': 461, 'you': 1068, 'verse': 79, '1': 39, "don't": 205, 'know': 213, 'how': 72, 'does': 6, 'it': 317, 'go': 95, 'promise': 13, 'that': 230, 'love': 112, 'so': 134, "i'll": 71, 'bet': 3, 'on': 171, 'me': 500, "you're": 136, 'bulletproof': 1, "let's": 25, 'throw': 3, 'away': 70, 'our': 37, 'backup': 1, 'plans': 9, 'people': 11, 'might': 12, 'not': 76, 'understand': 17, 'who': 35, 'cares': 2, 'about': 103, 'if': 107, 'they': 22, 'approve': 1, "i'd": 16, 'face': 13, 'them': 16, 'be': 189, 'with': 83, 'we': 188, 'could': 43, 'dance': 5, 'flowers': 2, '2': 39, 'heard': 7, 'once': 4, 'wise': 2, 'man': 5, 'said': 25, 'only': 43, 'fools': 2, 'rushing': 2, 'in': 203, "i'm": 274, 'type': 5, 'overthink': 4, 'when': 123, 'something': 35, 'feels': 10, 'right': 41, 'mean': 31, 'every': 47, 'word': 5, 'paint': 1, 'world': 25, 'deserve': 1, 'color': 1, "you'd": 3, 'imagine': 13, "can't": 229, 'wait': 15, 'for': 121, 'happen': 2, "'cause": 70, '3': 7, 'intro': 7, '05': 4, 'rollercoaster': 4, 'ride': 5, 'hoping': 9, 'change': 26, 'your': 159, 'mind': 53, 'let': 84, 'never': 77, 'been': 64, 'sure': 9, 'my': 344, 'life': 26, 'sunlight': 1, 'rainy': 1, 'day': 10, 'would': 38, 'heart': 47, 'walked': 5, 'mess': 13, 'now': 88, 'wreck': 1, 'waiting': 2, 'moment': 16, 'down': 57, 'cut': 4, 'cord': 1, 'what': 132, 'do': 140, 'skydive': 1, 'without': 29, 'parachute': 1, 'baby': 88, 'help': 26, 'out': 59, 'scared': 2, 'gonna': 24, 'wake': 30, 'up': 122, "you'll": 19, 'pre-chorus': 46, 'this': 150, 'feeling': 26, "doesn't": 8, 'fade': 2, 'no': 119, 'matter': 8, 'hard': 31, 'try': 20, 'always': 35, 'think': 44, 'at': 42, 'same': 21, 'time': 86, 'night': 34, 'terrified': 3, 'turn': 17, 'around': 35, 'say': 68, 'goodbye': 6, "i've": 39, "there's": 38, 'door': 6, 'heaven': 2, 'key': 1, 'had': 18, 'beg': 1, 'knees': 11, 'oh': 190, 'please': 33, 'anything': 5, 'has': 8, 'changed': 1, 'one': 93, 'next': 5, 'bridge': 27, 'want': 91, 'fly': 11, 'darling': 15, 'yeah': 178, 'ooh-ooh': 3, 'she': 58, 'show': 28, 'was': 44, 'afraid': 11, 'being': 3, 'alone': 28, 'too': 46, 'much': 41, 'though': 17, 'everyone': 2, 'strong': 8, "didn't": 31, 'barely': 1, 'carry': 1, 'knew': 10, 'okay': 5, 'get': 156, 'her': 28, 'way': 30, 'sometimes': 16, 'gets': 14, 'gotta': 45, 'realize': 3, 'fog': 3, 'will': 51, 'clear': 3, 'have': 71, 'because': 12, "we're": 45, 'tell': 73, 'herself': 1, 'use': 2, 'just': 183, 'fine': 5, 'got': 65, 'loose': 1, 'focus': 3, 'hand': 7, "we'll": 8, 'leave': 27, 'tomorrow': 4, 'sleep': 4, 'make': 38, 'things': 10, 'breakfast': 2, 'like': 152, 'before': 19, 'stay': 19, 'here': 19, 'lay': 9, 'arms': 8, 'gone': 13, 'am': 26, 'keeping': 6, 'warm': 4, 'act': 12, 'can': 67, 'more': 22, 'lying': 3, 'bed': 5, 'whether': 1, 'wrong': 29, 'or': 17, 'sense': 3, 'of': 146, 'morning': 10, 'over': 25, 'forget': 18, 'watch': 16, 'sneak': 2, 'asleep': 5, 'miles': 9, 'road': 6, 'wishing': 1, 'everything': 26, 'dream': 36, 're-rewind': 1, 'friday': 2, 'lies': 2, 'where': 57, 'headed': 1, 'probably': 1, "should've": 4, 'known': 3, 'pretty': 4, 'forgive': 2, 'fool': 2, 'told': 9, 'twice': 4, 'regret': 1, 'turns': 4, 'replace': 4, 'permanent': 4, 'erase': 6, 'remember': 14, 'kiss': 12, 'takes': 16, 'memory': 4, 'aftertaste': 5, 'close': 22, 'eyes': 23, 'hide': 5, 'everywhere': 4, 'smell': 1, 'sheets': 1, "weren't": 5, 'ready': 20, 'left': 11, 'there': 22, 'hurts': 4, 'worse': 5, 'nobody': 11, 'fair': 5, 'threw': 1, 'waste': 6, 'wonder': 22, 'back': 59, 'did': 17, 'truth': 7, 'thought': 24, 'end': 8, 'from': 37, 'start': 14, 'trying': 18, 'used': 6, 'last': 16, 'forever': 18, 'harm': 4, "stringin'": 4, 'along': 8, 'spare': 4, 'breathe': 13, 'suffocating': 4, 'coming': 27, 'air': 78, 'tryna': 3, 'put': 31, 'two': 7 ...

# %% [markdown]
# Creates a dictionary grouping all the words by Gender and then by Genre

# %%
maleDict={}
femaleDict={}
otherDict={}

maleDict.update({'Pop':popMaleValue})
maleDict.update({'Rock':rockMaleValue})
maleDict.update({'Hip-Hop':hiphopMaleValue})
maleDict.update({'Soul':soulMaleValue})
maleDict.update({'EDM':edmMaleValue})
maleDict.update({'R&B':rbMaleValue})
maleDict.update({'Alternative':alternativeMaleValue})
maleDict.update({'Country':countryMaleValue})
maleDict.update({'Jazz':jazzMaleValue})
maleDict.update({'Metal':metalMaleValue})
maleDict.update({'Folk':folkMaleValue})
maleDict.update({'Punk':punkMaleValue})


femaleDict.update({'Pop':popFemaleValue})
femaleDict.update({'Rock':rockFemaleValue})
femaleDict.update({'Hip-Hop':hiphopFemaleValue})
femaleDict.update({'Soul':soulFemaleValue})
femaleDict.update({'EDM':edmFemaleValue})
femaleDict.update({'R&B':rbFemaleValue})
femaleDict.update({'Alternative':alternativeFemaleValue})
femaleDict.update({'Country':countryFemaleValue})
femaleDict.update({'Jazz':jazzFemaleValue})
femaleDict.update({'Metal':metalFemaleValue})
femaleDict.update({'Folk':folkFemaleValue})
femaleDict.update({'Punk':punkFemaleValue})


otherDict.update({'Pop':popOtherValue})
otherDict.update({'Rock':rockOtherValue})
otherDict.update({'Hip-Hop':hiphopOtherValue})
otherDict.update({'Soul':soulOtherValue})
otherDict.update({'EDM':edmOtherValue})
otherDict.update({'R&B':rbOtherValue})
otherDict.update({'Alternative':alternativeOtherValue})
otherDict.update({'Country':countryOtherValue})
otherDict.update({'Jazz':jazzOtherValue})
otherDict.update({'Metal':metalOtherValue})
otherDict.update({'Folk':folkOtherValue})
otherDict.update({'Punk':punkOtherValue})


totalDict={}
totalDict.update({'Male': maleDict})
totalDict.update({'Female': femaleDict})
totalDict.update({'other': otherDict})

# %% [markdown]
# Writes to a json file

# %%
with open("totalData.json","w") as cp: #writes to a json file (total Data)
  json.dump(totalDict,cp,indent=4)

with open("wordsPerGenre.json","w") as cp: #writes to a json file
  json.dump(genreDict,cp,indent=4)
with open("wordsPerGender.json","w") as cp: #writes to a json file
  json.dump(genderDict,cp,indent=4)
